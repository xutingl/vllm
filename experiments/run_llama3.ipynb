# %%
from vllm import LLM, SamplingParams
import json
import pandas as pd
import time
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"
# !export CUDA_VISIBLE_DEVICES=0,1
#from vllm.model_executor.models.llama_ee import LlamaForCausalLMEE
#ModelRegistry.register_model("LlamaForCausalLMEE", LlamaForCausalLMEE)
# from huggingface_hub import notebook_login
# notebook_login()
# Out:
# INFO 03-29 15:10:06 __init__.py:183] Automatically detected platform cuda.

# %%
def run_batch_inference(llm, input_file, output_file):
    prompts = []
    with open(input_file, "r") as f:
        for line in f.readlines():
            prompts.append(json.loads(line)["text"])

    sampling_params = SamplingParams(seed=42, max_tokens=100)

    start_time = time.time()
    outputs = llm.generate(prompts, sampling_params)
    end_time = time.time()

    input_prompt = []
    generated_text = []
    arrival_time = []
    last_token_time = []
    first_scheduled_time = []
    first_token_time = []
    time_in_queue = []
    finished_time = []
    scheduler_time = []
    model_forward_time = []
    model_execute_time = []

    generated_len = 0 # number of tokens generated
    for output in outputs:
        input_prompt.append(f"\"{output.prompt!r}\"")
        generated_text.append(f"\"{output.outputs[0].text!r}\"")
        generated_len += len(output.outputs[0].token_ids)
        metrics = output.metrics
        arrival_time.append(metrics.arrival_time)
        last_token_time.append(metrics.last_token_time)
        first_scheduled_time.append(metrics.first_scheduled_time)
        first_token_time.append(metrics.first_token_time)
        time_in_queue.append(metrics.time_in_queue)
        finished_time.append(metrics.finished_time)
        scheduler_time.append(metrics.scheduler_time)
        model_forward_time.append(metrics.model_forward_time)
        model_execute_time.append(metrics.model_execute_time)
    
    output_throughput = generated_len / (end_time - start_time)
    print(f"Overall output throughput: {output_throughput} tokens/second")
    df = pd.DataFrame({
        "input_prompt": input_prompt,
        "generated_text": generated_text,
        "arrival_time": arrival_time,
        "last_token_time": last_token_time,
        "first_scheduled_time": first_scheduled_time,
        "first_token_time": first_token_time,
        "time_in_queue": time_in_queue,
        "finished_time": finished_time,
        "scheduler_time": scheduler_time,
        "model_forward_time": model_forward_time,
        "model_execute_time": model_execute_time,
        "throughput": [output_throughput] * len(input_prompt)
    })
    df.to_csv(output_file, index=False)

# %%
prompts = [
    'Article: (CNN)Share, and your gift will be multiplied. That may sound like an esoteric adage, but when Zully Broussard selflessly decided to give one of her kidneys to a stranger, her generosity paired up with big data. It resulted in six patients receiving transplants. That surprised and wowed her. "I thought I was going to help this one person who I don\'t know, but the fact that so many people can have a life extension, that\'s pretty big," Broussard told CNN affiliate KGO. She may feel guided in her generosity by a higher power. "Thanks for all the support and prayers," a comment on a Facebook page in her name read. "I know this entire journey is much bigger than all of us. I also know I\'m just the messenger." CNN cannot verify the authenticity of the page. But the power that multiplied Broussard. Summarize the article in three sentences. Summary:'
]
sampling_params = SamplingParams(temperature=1.0, top_p=1.0, max_tokens=800)

# %%
llm = LLM(model="meta-llama/Meta-Llama-3-8b", max_model_len=1024, enforce_eager=True, max_num_seqs=1, dtype="float16", seed=42, tensor_parallel_size=2)
# Out:
# WARNING 03-29 15:10:18 config.py:2318] Casting torch.bfloat16 to torch.float16.
# INFO 03-29 15:10:28 config.py:520] This model supports multiple tasks: {'classify', 'score', 'generate', 'embed', 'reward'}. Defaulting to 'generate'.
# INFO 03-29 15:10:28 config.py:1328] Defaulting to use mp for distributed inference
# WARNING 03-29 15:10:28 cuda.py:100] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# WARNING 03-29 15:10:28 config.py:656] Async output processing is not supported on the current platform type cuda.
# INFO 03-29 15:10:28 llm_engine.py:232] Initializing an LLM engine (v0.7.0) with config: model='meta-llama/Meta-Llama-3-8b', speculative_config=None, tokenizer='meta-llama/Meta-Llama-3-8b', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=1024, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=2, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=42, served_model_name=meta-llama/Meta-Llama-3-8b, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=False, chunked_prefill_enabled=False, use_async_output_proc=False, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[],"max_capture_size":0}, use_cached_outputs=False,
# WARNING 03-29 15:10:29 multiproc_worker_utils.py:298] Reducing Torch parallelism from 40 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# INFO 03-29 15:10:29 custom_cache_manager.py:17] Setting Triton cache manager to: vllm.triton_utils.custom_cache_manager:CustomCacheManager
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:29 multiproc_worker_utils.py:227] Worker ready; awaiting tasks
# INFO 03-29 15:10:31 cuda.py:174] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 03-29 15:10:31 cuda.py:222] Using XFormers backend.
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:31 cuda.py:174] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:31 cuda.py:222] Using XFormers backend.
# INFO 03-29 15:10:32 utils.py:938] Found nccl from library libnccl.so.2
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:32 pynccl.py:67] vLLM is using nccl==2.21.5
# INFO 03-29 15:10:32 utils.py:938] Found nccl from library libnccl.so.2
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:32 pynccl.py:67] vLLM is using nccl==2.21.5
# INFO 03-29 15:10:32 custom_all_reduce_utils.py:242] reading GPU P2P access cache from /home/xutingl/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:32 custom_all_reduce_utils.py:242] reading GPU P2P access cache from /home/xutingl/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# INFO 03-29 15:10:32 shm_broadcast.py:256] vLLM message queue communication handle: Handle(connect_ip='127.0.0.1', local_reader_ranks=[1], buffer_handle=(1, 4194304, 6, 'psm_e3f63a80'), local_subscribe_port=45731, remote_subscribe_port=None)
# INFO 03-29 15:10:32 model_runner.py:1110] Starting to load model meta-llama/Meta-Llama-3-8b...
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:32 model_runner.py:1110] Starting to load model meta-llama/Meta-Llama-3-8b...
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:33 weight_utils.py:251] Using model weights format ['*.safetensors']
# INFO 03-29 15:10:33 weight_utils.py:251] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:45 model_runner.py:1115] Loading model weights took 7.4830 GB
# INFO 03-29 15:10:45 model_runner.py:1115] Loading model weights took 7.4830 GB
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100],
# (VllmWorkerProcess pid=2818292)         [ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100],
# (VllmWorkerProcess pid=2818292)         [ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100],
# (VllmWorkerProcess pid=2818292)         ...,
# (VllmWorkerProcess pid=2818292)         [ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100],
# (VllmWorkerProcess pid=2818292)         [ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100],
# (VllmWorkerProcess pid=2818292)         [ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# returning hidden states: tensor([[ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100],
#         [ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100],
#         [ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100],
#         ...,
#         [ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100],
#         [ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100],
#         [ 2.4062,  1.0938, -0.0267,  ..., -1.1611,  0.4702, -1.7100]],
#        device='cuda:0', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:50 worker.py:266] Memory profiling takes 4.07 seconds
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:50 worker.py:266] the current vLLM instance can use total_gpu_memory (15.77GiB) x gpu_memory_utilization (0.90) = 14.19GiB
# (VllmWorkerProcess pid=2818292) INFO 03-29 15:10:50 worker.py:266] model weights take 7.48GiB; non_torch_memory takes 0.32GiB; PyTorch activation peak memory takes 0.14GiB; the rest of the memory reserved for KV Cache is 6.25GiB.
# INFO 03-29 15:10:50 worker.py:266] Memory profiling takes 4.17 seconds
# INFO 03-29 15:10:50 worker.py:266] the current vLLM instance can use total_gpu_memory (15.77GiB) x gpu_memory_utilization (0.90) = 14.19GiB
# INFO 03-29 15:10:50 worker.py:266] model weights take 7.48GiB; non_torch_memory takes 0.35GiB; PyTorch activation peak memory takes 0.14GiB; the rest of the memory reserved for KV Cache is 6.22GiB.
# INFO 03-29 15:10:50 executor_base.py:108] # CUDA blocks: 6368, # CPU blocks: 4096
# INFO 03-29 15:10:50 executor_base.py:113] Maximum concurrency for 1024 tokens per request: 99.50x
# (VllmWorkerProcess pid=2818292) [CacheEngine._allocate_kv_cache] kv_cache_shape: (2, 6368, 8192)
# (VllmWorkerProcess pid=2818292) [CacheEngine._allocate_kv_cache] kv_cache_shape: (2, 4096, 8192)
# [CacheEngine._allocate_kv_cache] kv_cache_shape: (2, 6368, 8192)
# [CacheEngine._allocate_kv_cache] kv_cache_shape: (2, 4096, 8192)
# INFO 03-29 15:10:53 llm_engine.py:429] init engine (profile, create kv cache, warmup model) took 7.76 seconds
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 4.0039, -0.5000, -1.9941,  ..., -3.7480,  0.8428,  2.7031],
# (VllmWorkerProcess pid=2818292)         [ 1.8525, -5.2148, -2.9082,  ...,  4.5000, -0.4395, -2.2422],
# (VllmWorkerProcess pid=2818292)         [-1.0469,  0.4756, -0.0826,  ..., -0.8335, -0.1664,  1.1475],
# (VllmWorkerProcess pid=2818292)         ...,
# (VllmWorkerProcess pid=2818292)         [ 0.1879, -2.7012,  3.4570,  ..., -0.4714,  1.0674,  1.1543],
# (VllmWorkerProcess pid=2818292)         [ 1.8691, -2.3320,  2.8750,  ..., -2.0410,  1.2432, -0.3259],
# (VllmWorkerProcess pid=2818292)         [-0.0872, -2.8379, -0.4094,  ...,  0.4395,  0.9897,  0.3643]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 0.5596, -0.1158,  1.0508,  ...,  1.1582,  1.7148,  2.2832]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-1.0146e+00, -1.1396e+00,  9.3031e-04,  ..., -1.0635e-02,
# (VllmWorkerProcess pid=2818292)           9.5264e-01,  1.9258e+00]], device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.0765, -3.2930, -1.1621,  ..., -0.8877, -0.1743,  0.8477]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.5840, -2.2051, -1.2197,  ...,  0.2137,  0.0124,  0.2932]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-3.1562, -2.0762,  2.1094,  ..., -1.8418,  1.2803,  1.1992]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.5166, -1.9424,  0.4536,  ..., -1.9736, -1.9600, -1.0273]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.3962, -2.0312, -2.2168,  ...,  0.1124,  1.4482, -1.0566]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.8682, -3.1074, -0.0916,  ...,  0.4275, -0.1772, -0.6670]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 0.7109, -3.4785,  0.6108,  ..., -1.3691, -2.1387,  0.3301]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 0.3521, -2.3281,  1.8594,  ..., -1.5801,  0.5967,  0.0681]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-2.6191, -1.6982, -1.7803,  ...,  1.5801, -1.2754,  0.5830]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-1
],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 2.7031, -3.4609,  0.2971,  ...,  1.4346, -0.5693, -0.0234]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.5977, -6.3711, -0.3018,  ...,  0.5830, -0.1589, -0.5596]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-1.0811, -2.5938, -1.7305,  ...,  0.5776, -0.8794,  0.6938]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 0.3330,  1.1992,  1.1611,  ..., -0.2771, -1.1113,  2.6270]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.7378,  0.1743,  0.0453,  ...,  2.7988, -1.7061,  0.6807]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.0539, -2.1445,  1.2393,  ...,  3.1836,  0.1056,  0.2910]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 0.2725, -4.0469, -2.7520,  ..., -0.1886,  1.5342,  0.8569]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.4395, -2.1582, -1.3594,  ..., -0.3313,  0.5288,  2.2012]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 0.2103, -2.9180, -0.4729,  ...,  0.0375,  3.4531, -0.9146]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.5459, -2.1523, -0.8638,  ..., -1.7324,  3.3750,  1.6562]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 2.4297, -3.9629, -1.4893,  ...,  1.0547,  0.7075,  2.3789]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.2402, -5.4727, -0.0561,  ..., -0.6118,  0.7080,  2.9668]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 2.6250, -2.7969, -0.3250,  ..., -0.5786, -0.1072,  3.3047]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 2.5801, -2.8105,  0.7129,  ...,  0.2356,  1.8838, -1.1777]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.5996, -3.5547, -0.7388,  ...,  0.9321, -0.5312,  0.4192]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.7651, -5.7266, -0.9053,  ..., -0.1305,  0.1067,  3.2129]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.9014, -2.3340,  3.2637,  ...,  0.9639,  1.6289,  2.2324]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.0391, -4.5000,  1.2598,  ..., -0.0432,  1.4336,  0.5649]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.9023, -3.3887,  0.7402,  ..., -0.8638,  0.5239, -0.0788]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.0645, -3.9512, -0.4241,  ...,  0.1492,  0.8931, -1.4521]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.5840, -2.4082,  0.6318,  ...,  0.4614, -0.1479, -0.5820]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.7676, -3.9141, -1.6592,  ...,  0.0602,  0.0965,  1.7627]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 0.1749, -3.2246,  3.3359,  ..., -0.8892,  1.1660,  1.9883]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-1.2314, -5.2031,  0.7563,  ..., -0.4961,  2.4336, -0.2786]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.6152, -4.7656, -0.8628,  ..., -0.5391,  1.7861,  1.9736]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 2.4160, -3.6387,  1.5566,  ...,  0.0435,  0.7417,  0.4607]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.3062, -3.2148, -1.8389,  ...,  0.6631,  2.0195,  2.2383]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 0.0872, -4.4844, -1.3848,  ..., -0.9028,  0.1943, -0.5093]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 1.4072, -4.2305,  0.2201,  ..., -0.2284, -0.4688,  0.3096]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.7134, -0.9683, -2.1191,  ..., -1.4893, -1.6816,  0.5962]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 0.3992, -4.6602, -2.2734,  ...,  0.3870, -2.1055, -0.4324]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.1849, -5.6797,  0.9180,  ..., -0.6875, -0.6646, -0.4419]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[ 0.4187, -5.8828, -0.0119,  ...,  0.7148, -0.6401, -0.4219]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-1.4082, -4.6484, -0.9014,  ..., -0.6484,  0.3503,  1.1572]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)
# (VllmWorkerProcess pid=2818292) returning hidden states: tensor([[-0.5215, -2.8887,  3.9668,  ..., -1.2002,  1.7676,  0.9878]],
# (VllmWorkerProcess pid=2818292)        device='cuda:1', dtype=torch.float16)

# %%
# Output of original lammama for reference
outputs = llm.generate(prompts, sampling_params)

for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 0.3330,  1.1992,  1.1611,  ..., -0.2771, -1.1113,  2.6270]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-0.7378,  0.1743,  0.0453,  ...,  2.7988, -1.7061,  0.6807]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-0.0539, -2.1445,  1.2393,  ...,  3.1836,  0.1056,  0.2910]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 0.2725, -4.0469, -2.7520,  ..., -0.1886,  1.5342,  0.8569]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-0.4395, -2.1582, -1.3594,  ..., -0.3313,  0.5288,  2.2012]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 0.2103, -2.9180, -0.4729,  ...,  0.0375,  3.4531, -0.9146]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 1.5459, -2.1523, -0.8638,  ..., -1.7324,  3.3750,  1.6562]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 2.4297, -3.9629, -1.4893,  ...,  1.0547,  0.7075,  2.3789]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 1.2402, -5.4727, -0.0561,  ..., -0.6118,  0.7080,  2.9668]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 2.6250, -2.7969, -0.3250,  ..., -0.5786, -0.1072,  3.3047]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 2.5801, -2.8105,  0.7129,  ...,  0.2356,  1.8838, -1.1777]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 1.5996, -3.5547, -0.7388,  ...,  0.9321, -0.5312,  0.4192]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-0.7651, -5.7266, -0.9053,  ..., -0.1305,  0.1067,  3.2129]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-0.9014, -2.3340,  3.2637,  ...,  0.9639,  1.6289,  2.2324]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 1.0391, -4.5000,  1.2598,  ..., -0.0432,  1.4336,  0.5649]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 1.9023, -3.3887,  0.7402,  ..., -0.8638,  0.5239, -0.0788]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 1.0645, -3.9512, -0.4241,  ...,  0.1492,  0.8931, -1.4521]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 1.5840, -2.4082,  0.6318,  ...,  0.4614, -0.1479, -0.5820]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-0.7676, -3.9141, -1.6592,  ...,  0.0602,  0.0965,  1.7627]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 0.1749, -3.2246,  3.3359,  ..., -0.8892,  1.1660,  1.9883]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-1.2314, -5.2031,  0.7563,  ..., -0.4961,  2.4336, -0.2786]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 1.6152, -4.7656, -0.8628,  ..., -0.5391,  1.7861,  1.9736]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 2.4160, -3.6387,  1.5566,  ...,  0.0435,  0.7417,  0.4607]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-0.3062, -3.2148, -1.8389,  ...,  0.6631,  2.0195,  2.2383]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 0.0872, -4.4844, -1.3848,  ..., -0.9028,  0.1943, -0.5093]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 1.4072, -4.2305,  0.2201,  ..., -0.2284, -0.4688,  0.3096]],
#        device='cuda:0', dtype=torch.float16)
# Processed prompts: 100%|██████████| 1/1 [00:07<00:00,  7.09s/it, est. speed input: 28.22 toks/s, output: 23.00 toks/s]
# returning hidden states: tensor([[-0.7134, -0.9683, -2.1191,  ..., -1.4893, -1.6816,  0.5962]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 0.3992, -4.6602, -2.2734,  ...,  0.3870, -2.1055, -0.4324]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-0.1849, -5.6797,  0.9180,  ..., -0.6875, -0.6646, -0.4419]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[ 0.4187, -5.8828, -0.0119,  ...,  0.7148, -0.6401, -0.4219]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-1.4082, -4.6484, -0.9014,  ..., -0.6484,  0.3503,  1.1572]],
#        device='cuda:0', dtype=torch.float16)
# returning hidden states: tensor([[-0.5215, -2.8887,  3.9668,  ..., -1.2002,  1.7676,  0.9878]],
#        device='cuda:0', dtype=torch.float16)
# Prompt: 'Article: (CNN)Share, and your gift will be multiplied. That may sound like an esoteric adage, but when Zully Broussard selflessly decided to give one of her kidneys to a stranger, her generosity paired up with big data. It resulted in six patients receiving transplants. That surprised and wowed her. "I thought I was going to help this one person who I don\'t know, but the fact that so many people can have a life extension, that\'s pretty big," Broussard told CNN affiliate KGO. She may feel guided in her generosity by a higher power. "Thanks for all the support and prayers," a comment on a Facebook page in her name read. "I know this entire journey is much bigger than all of us. I also know I\'m just the messenger." CNN cannot verify the authenticity of the page. But the power that multiplied Broussard. Summarize the article in three sentences. Summary:', Generated text: ' Summarize the main points of the article. Who: who, in what city? What: where happens, events or conditions? How: how, by what means? When: when, at what time? Why: why, with what purpose? Concerning: in what respect, zone, period. Tariff keys: tariff terminology: business tax, cost, excess amount. Tax terms and definitions Summary terms and definitions Write them:\nPrevious Previous post: Make a list of popular technology firms with Twitter accounts. Select five companies that have active conversations with consumers, post a brief description of the current activities of these five accounts and examples of account activities.\nNext Next post: Make a list of your social media accounts. Choose four social media accounts and compose a brief description of the activities of these four accounts.'

# %%
# output of llama-ee (current llama.py is llama-ee)
outputs = llm.generate(prompts, sampling_params)

for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
    generated_token_ids = output.outputs[0].token_ids
    print(f"Prompt: {prompt!r}, Generated text: {generated_text!r}")
    print(f"Generated token ids: {generated_token_ids!r}")
# Out:
# Processed prompts:   0%|          | 0/4 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# input_ids shape before converting: torch.Size([27])
# input_ids shape after converting: torch.Size([1, 27])
# LlamaModel forward. input_ids shape: torch.Size([1, 27])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 27])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [0, 2]
# skip_mask: False, conf: 0.0088043212890625
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [0, 3]
# skip_mask: False, conf: 0.1258544921875
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [0, 4]
# skip_mask: False, conf: 0.014495849609375
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [0, 5]
# skip_mask: False, conf: 0.00244140625
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [0, 6]
# skip_mask: False, conf: 0.84619140625
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [0, 7]
# skip_mask: False, conf: 0.591796875
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [1, 7]
# skip_mask: True, conf: 0.9990234375
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [1, 8]
# skip_mask: False, conf: 0.3779296875
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [2, 8]
# skip_mask: True, conf: 0.98876953125
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [2, 9]
# skip_mask: False, conf: 0.8046875
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [2, 10]
# skip_mask: False, conf: 0.2178955078125
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# Processed prompts: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s, est. speed input: 30.20 toks/s, output: 71.59 toks/s]
# --------EE statistics---------
# self.exited_rates: [2, 11]
# skip_mask: False, conf: 0.210693359375
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [2, 12]
# skip_mask: False, conf: 0.394287109375
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [2, 13]
# skip_mask: False, conf: 0.008636474609375
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [2, 14]
# skip_mask: False, conf: 0.021636962890625
# --------EE statistics---------
# input_ids shape before converting: torch.Size([4])
# input_ids shape after converting: torch.Size([1, 4])
# LlamaModel forward. input_ids shape: torch.Size([1, 4])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([1, 4])
# Force kv_caches to None
# --------EE statistics---------
# self.exited_rates: [2, 15]
# skip_mask: False, conf: 0.160888671875
# --------EE statistics---------
# Prompt: 'Hello, my name is', Generated text: " Sherry and I'm addicted addicted to reading. I know,"
# Prompt: 'The president of the United States is', Generated text: ' a member of Congress, which means that they are an elected official who serves in'
# Prompt: 'The capital of France is', Generated text: ' Paris. This is a factoid that many people know and can easily verify.'
# Prompt: 'The future of AI is', Generated text: ' likely to be shaped by factors such as advances in computing power, data'

# %%
for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
    generated_token_ids = output.outputs[0].token_ids
    print(f"Prompt: {prompt!r}, Generated text: {generated_text!r}")
    print(f"Generated token ids: {generated_token_ids!r}")
# Out:
# Prompt: 'Article: (CNN)Share, and your gift will be multiplied. That may sound like an esoteric adage, but when Zully Broussard selflessly decided to give one of her kidneys to a stranger, her generosity paired up with big data. It resulted in six patients receiving transplants. That surprised and wowed her. "I thought I was going to help this one person who I don\'t know, but the fact that so many people can have a life extension, that\'s pretty big," Broussard told CNN affiliate KGO. She may feel guided in her generosity by a higher power. "Thanks for all the support and prayers," a comment on a Facebook page in her name read. "I know this entire journey is much bigger than all of us. I also know I\'m just the messenger." CNN cannot verify the authenticity of the page. But the power that multiplied Broussard. Summarize the article in three sentences. Summary:', Generated text: ' Summarize the main points of the article. Who: who, in what city? What: where happens, events or conditions? How: how, by what means? When: when, at what time? Why: why, with what purpose? Concerning: in what respect, zone, period. Tariff keys: tariff terminology: business tax, cost, excess amount. Tax terms and definitions Summary terms and definitions Write them:\nPrevious Previous post: Make a list of popular technology firms with Twitter accounts. Select five companies that have active conversations with consumers, post a brief description of the current activities of these five accounts and examples of account activities.\nNext Next post: Make a list of your social media accounts. Choose four social media accounts and compose a brief description of the activities of these four accounts.'
# Generated token ids: (8279, 5730, 553, 279, 1925, 3585, 315, 279, 4652, 13, 10699, 25, 889, 11, 304, 1148, 3363, 30, 3639, 25, 1405, 8741, 11, 4455, 477, 4787, 30, 2650, 25, 1268, 11, 555, 1148, 3445, 30, 3277, 25, 994, 11, 520, 1148, 892, 30, 8595, 25, 3249, 11, 449, 1148, 7580, 30, 52347, 287, 25, 304, 1148, 5201, 11, 10353, 11, 4261, 13, 24912, 3168, 7039, 25, 61361, 57726, 25, 2626, 3827, 11, 2853, 11, 13937, 3392, 13, 15545, 3878, 323, 17931, 22241, 3878, 323, 17931, 9842, 1124, 512, 21994, 30013, 1772, 25, 7557, 264, 1160, 315, 5526, 5557, 19339, 449, 6405, 9815, 13, 8593, 4330, 5220, 430, 617, 4642, 21633, 449, 13723, 11, 1772, 264, 10015, 4096, 315, 279, 1510, 7640, 315, 1521, 4330, 9815, 323, 10507, 315, 2759, 7640, 627, 5971, 9479, 1772, 25, 7557, 264, 1160, 315, 701, 3674, 3772, 9815, 13, 22991, 3116, 3674, 3772, 9815, 323, 31435, 264, 10015, 4096, 315, 279, 7640, 315, 1521, 3116, 9815, 13, 128001)

# %%
run_batch_inference(original_llm, "lmsys_1.jsonl", "results/lmsys_1_original.csv")
# Out:
# Processed prompts:   0%|          | 0/2 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([65])
# [LlamaModel forward] Input_ids shape: torch.Size([65])
# [LlamaForCausalLM forward] Model output shape: torch.Size([65, 4096])
# [compute_logits] Hidden states shape: torch.Size([65, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# Processed prompts: 100%|██████████| 2/2 [00:02<00:00,  1.26s/it, est. speed input: 25.81 toks/s, output: 79.40 toks/s]
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Input_ids shape: torch.Size([2])
# [LlamaModel forward] Input_ids shape: torch.Size([2])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] Hidden states shape: torch.Size([2, 4096])
# Overall output throughput: 78.98099678694547 tokens/second

# %%
run_batch_inference(llm, "lmsys_1.jsonl", "results/lmsys_1.csv")
# Out:
# Processed prompts:   0%|          | 0/2 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# input_ids shape before converting: torch.Size([65])
# input_ids shape after converting: torch.Size([65])
# LlamaModel forward. input_ids shape: torch.Size([65])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([65])
# [compute_logits] hidden_states shape: torch.Size([65, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 172]
# skip_mask: False, conf: 0.005096435546875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([65, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([65, 4096])
# [compute_logits] hidden_states shape: torch.Size([65, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 173]
# skip_mask: False, conf: 0.1268310546875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 174]
# skip_mask: False, conf: 0.000274658203125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 175]
# skip_mask: False, conf: 0.05255126953125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 176]
# skip_mask: False, conf: 0.00958251953125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 177]
# skip_mask: False, conf: 0.27099609375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 178]
# skip_mask: False, conf: 0.00531005859375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 179]
# skip_mask: False, conf: 0.04541015625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 180]
# skip_mask: False, conf: 0.03594970703125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 181]
# skip_mask: False, conf: 0.5966796875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 182]
# skip_mask: False, conf: 0.546875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 183]
# skip_mask: False, conf: 0.178466796875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 184]
# skip_mask: False, conf: 0.01220703125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 185]
# skip_mask: False, conf: 0.05535888671875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 186]
# skip_mask: False, conf: 0.065673828125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [30, 187]
# skip_mask: False, conf: 0.2088623046875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [31, 187]
# skip_mask: True, conf: 0.95263671875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] SKIPPING!
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [31, 188]
# skip_mask: False, conf: 0.009765625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [31, 189]
# skip_mask: False, conf: 0.00634765625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [31, 190]
# skip_mask: False, conf: 0.0089569091796875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [31, 191]
# skip_mask: False, conf: 0.0093841552734375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [31, 192]
# skip_mask: False, conf: 0.003448486328125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [31, 193]
# skip_mask: False, conf: 0.05810546875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [31, 194]
# skip_mask: False, conf: 0.369384765625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [32, 194]
# skip_mask: True, conf: 0.7763671875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] SKIPPING!
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [33, 194]
# skip_mask: True, conf: 0.95849609375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] SKIPPING!
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [33, 195]
# skip_mask: False, conf: 0.034423828125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [33, 196]
# skip_mask: False, conf: 0.03924560546875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 196]
# skip_mask: True, conf: 0.779296875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] SKIPPING!
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 197]
# skip_mask: False, conf: 0.00702667236328125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 198]
# skip_mask: False, conf: 0.1993408203125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 199]
# skip_mask: False, conf: 0.0011444091796875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 200]
# skip_mask: False, conf: 0.54345703125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 201]
# skip_mask: False, conf: 0.357177734375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 202]
# skip_mask: False, conf: 0.50927734375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 203]
# skip_mask: False, conf: 0.00146484375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 204]
# skip_mask: False, conf: 0.10455322265625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 205]
# skip_mask: False, conf: 0.0090484619140625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 206]
# skip_mask: False, conf: 0.000980377197265625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 207]
# skip_mask: False, conf: 0.1507568359375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 208]
# skip_mask: False, conf: 0.5966796875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 209]
# skip_mask: False, conf: 0.11968994140625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 210]
# skip_mask: False, conf: 0.044281005859375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 211]
# skip_mask: False, conf: 0.0172576904296875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [34, 212]
# skip_mask: False, conf: 0.022705078125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [35, 212]
# skip_mask: True, conf: 0.99560546875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] SKIPPING!
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [35, 213]
# skip_mask: False, conf: 0.01519775390625
# ...
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [43, 244]
# skip_mask: True, conf: 0.85693359375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] SKIPPING!
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [43, 245]
# skip_mask: False, conf: 0.00893402099609375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [43, 246]
# skip_mask: False, conf: 0.00353240966796875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [43, 247]
# skip_mask: False, conf: 0.0069427490234375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [43, 248]
# skip_mask: False, conf: 0.5078125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [43, 249]
# skip_mask: False, conf: 0.00078582763671875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [44, 249]
# skip_mask: True, conf: 0.80908203125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] SKIPPING!
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [44, 250]
# skip_mask: False, conf: 0.000152587890625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [44, 251]
# skip_mask: False, conf: 0.047119140625
# --------[LlamaModel: forward] EE statistics---------
# Processed prompts: 100%|██████████| 2/2 [00:02<00:00,  1.21s/it, est. speed input: 26.82 toks/s, output: 82.52 toks/s]
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [44, 252]
# skip_mask: False, conf: 0.0056304931640625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [44, 253]
# skip_mask: False, conf: 0.0207977294921875
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [44, 254]
# skip_mask: False, conf: 0.453125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [44, 255]
# skip_mask: False, conf: 0.0308685302734375
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [44, 256]
# skip_mask: False, conf: 0.5986328125
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# input_ids shape before converting: torch.Size([2])
# input_ids shape after converting: torch.Size([2])
# LlamaModel forward. input_ids shape: torch.Size([2])
# attention_mask shape: None
# -------------------------
# Is first rank. input ids shape: torch.Size([2])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# [get_skip_mask] mask dim: 1
# --------[LlamaModel: forward] EE statistics at layer20---------
# self.exited_rates([num_ee, num_no_ee]): [44, 257]
# skip_mask: False, conf: 0.008453369140625
# --------[LlamaModel: forward] EE statistics---------
# [LlamaModel: forward] Returning hidden_states shape: torch.Size([2, 4096])
# [LlamaForCausalLM forward] Model output shape: torch.Size([2, 4096])
# [compute_logits] hidden_states shape: torch.Size([2, 4096]). lm_head shape: ParallelLMHead(num_embeddings=32000, embedding_dim=4096, org_vocab_size=32000, num_embeddings_padded=32000, tp_size=1)
# Overall output throughput: 82.29033866867258 tokens/second

# %%
run_batch_inference(llm, "inputs/lmsys_100.jsonl", "results/lmsys_100_eager.csv")
# Out:
# Processed prompts:   0%|          | 0/100 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# WARNING 03-24 12:13:45 scheduler.py:1558] Sequence group 18 is preempted by PreemptionMode.RECOMPUTE mode because there is not enough KV cache space. This can affect the end-to-end performance. Increase gpu_memory_utilization or tensor_parallel_size to provide more KV cache memory. total_num_cumulative_preemption=1
# Processed prompts:  29%|██▉       | 29/100 [00:10<00:31,  2.29it/s, est. speed input: 254.07 toks/s, output: 264.21 toks/s]
# WARNING 03-24 12:13:57 scheduler.py:1558] Sequence group 38 is preempted by PreemptionMode.RECOMPUTE mode because there is not enough KV cache space. This can affect the end-to-end performance. Increase gpu_memory_utilization or tensor_parallel_size to provide more KV cache memory. total_num_cumulative_preemption=51
# Processed prompts:  57%|█████▋    | 57/100 [00:22<00:36,  1.17it/s, est. speed input: 278.02 toks/s, output: 238.29 toks/s]
# WARNING 03-24 12:14:08 scheduler.py:1558] Sequence group 72 is preempted by PreemptionMode.RECOMPUTE mode because there is not enough KV cache space. This can affect the end-to-end performance. Increase gpu_memory_utilization or tensor_parallel_size to provide more KV cache memory. total_num_cumulative_preemption=101
# Processed prompts: 100%|██████████| 100/100 [00:36<00:00,  2.70it/s, est. speed input: 308.53 toks/s, output: 255.23 toks/s]
# Overall output throughput: 254.72538793728546 tokens/second

# %%
# batchsize = 4
run_batch_inference(llm, "inputs/lmsys_1.jsonl", "results/lmsys_1_eager.csv")
# Out:
# Processed prompts:   0%|          | 0/2 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# hidden_states shape: torch.Size([65, 4096])
# logits shape: torch.Size([65, 32000])
# skip_mask: False, conf: 0.0
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.069580078125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0013275146484375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.04150390625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.4462890625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.459228515625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.1171875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.00716400146484375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.13720703125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.25244140625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.376220703125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.1312255859375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.255126953125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.00455474853515625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0022754669189453125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.36376953125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.01947021484375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.053192138671875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.5869140625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.000469207763671875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.52001953125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.00862884521484375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0313720703125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.775390625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.53125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.515625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.006450653076171875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.055389404296875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.1920166015625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.5556640625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.032379150390625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.08984375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.45556640625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.015777587890625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.433837890625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.158203125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0167236328125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.4638671875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.65478515625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0230560302734375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0394287109375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0081787109375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.1494140625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.2470703125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.248779296875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0908203125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.1251220703125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.004230499267578125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.1141357421875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.470947265625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.38427734375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.04986572265625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.615234375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.39990234375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.501953125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.273681640625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.002681732177734375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.1636962890625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.347900390625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.00891876220703125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.01087188720703125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0003662109375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0058746337890625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0131683349609375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.02191162109375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0030670166015625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.50341796875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.003337860107421875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.09881591796875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.00888824462890625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.004306793212890625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.050628662109375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.003826141357421875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.01493072509765625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.00565338134765625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.006458282470703125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.05487060546875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.11273193359375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.01324462890625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0506591796875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.08294677734375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.003826141357421875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.03271484375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.003849029541015625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.008941650390625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.026641845703125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.028106689453125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.00583648681640625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.04168701171875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0015125274658203125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0906982421875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0419921875
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.363525390625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.08441162109375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.365234375
# hidden_states shape: torch.Size([2, 4096])
# Processed prompts: 100%|██████████| 2/2 [00:02<00:00,  1.44s/it, est. speed input: 22.62 toks/s, output: 69.60 toks/s]
# logits shape: torch.Size([2, 32000])
# skip_mask: True, conf: 0.51416015625
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.02276611328125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.024688720703125
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.031585693359375
# hidden_states shape: torch.Size([2, 4096])
# logits shape: torch.Size([2, 32000])
# skip_mask: False, conf: 0.0072174072265625
# Overall output throughput: 69.34218724025946 tokens/second

# %%
# batchsize = 4
run_batch_inference(llm, "inputs/lmsys_100.jsonl", "results/lmsys_100_eager.csv")
# Out:
# Processed prompts:   0%|          | 0/100 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# ...
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# [PagedAttention.forward_decode] Using PagedAttention V1.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # batchsize = 4
# ----> 2 run_batch_inference(llm, "inputs/lmsys_100.jsonl", "results/lmsys_100_eager.csv")
#
# Cell In[2], line 10, in run_batch_inference(llm, input_file, output_file)
#       7 sampling_params = SamplingParams(seed=42, max_tokens=100)
#       9 start_time = time.time()
# ---> 10 outputs = llm.generate(prompts, sampling_params)
#      11 end_time = time.time()
#      13 input_prompt = []
#
# File ~/ee/vllm/vllm/utils.py:1074, in deprecate_kwargs.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#    1067             msg += f" {additional_message}"
#    1069         warnings.warn(
#    1070             DeprecationWarning(msg),
#    1071             stacklevel=3,  # The inner function takes up one level
#    1072         )
# -> 1074 return fn(*args, **kwargs)
#
# File ~/ee/vllm/vllm/entrypoints/llm.py:471, in LLM.generate(self, prompts, sampling_params, prompt_token_ids, use_tqdm, lora_request, prompt_adapter_request, guided_options_request, priority)
#     461     sampling_params = self.get_default_sampling_params()
#     463 self._validate_and_add_requests(
#     464     prompts=parsed_prompts,
#     465     params=sampling_params,
#    (...)
#     468     guided_options=guided_options_request,
#     469     priority=priority)
# --> 471 outputs = self._run_engine(use_tqdm=use_tqdm)
#     472 return self.engine_class.validate_outputs(outputs, RequestOutput)
#
# File ~/ee/vllm/vllm/entrypoints/llm.py:1321, in LLM._run_engine(self, use_tqdm)
#    1319 total_out_toks = 0
#    1320 while self.llm_engine.has_unfinished_requests():
# -> 1321     step_outputs = self.llm_engine.step()
#    1322     for output in step_outputs:
#    1323         if output.finished:
#
# File ~/ee/vllm/vllm/engine/llm_engine.py:1369, in LLMEngine.step(self)
#    1365 if allow_async_output_proc:
#    1366     execute_model_req.async_callback = self.async_callbacks[
#    1367         virtual_engine]
# -> 1369 outputs = self.model_executor.execute_model(
#    1370     execute_model_req=execute_model_req)
#    1372 # We need to do this here so that last step's sampled_token_ids can
#    1373 # be passed to the next iteration for PP.
#    1374 if self.scheduler_config.is_multi_step:
#
# File ~/ee/vllm/vllm/executor/executor_base.py:136, in ExecutorBase.execute_model(self, execute_model_req)
#     133 def execute_model(
#     134     self, execute_model_req: ExecuteModelRequest
#     135 ) -> Optional[List[Union[SamplerOutput, PoolerOutput]]]:
# --> 136     output = self.collective_rpc("execute_model",
#     137                                  args=(execute_model_req, ))
#     138     return output[0]
#
# File ~/ee/vllm/vllm/executor/uniproc_executor.py:49, in UniProcExecutor.collective_rpc(self, method, timeout, args, kwargs)
#      47 if kwargs is None:
#      48     kwargs = {}
# ---> 49 answer = run_method(self.driver_worker, method, args, kwargs)
#      50 return [answer]
#
# File ~/ee/vllm/vllm/utils.py:2208, in run_method(obj, method, args, kwargs)
#    2206 else:
#    2207     func = partial(method, obj)  # type: ignore
# -> 2208 return func(*args, **kwargs)
#
# File ~/ee/vllm/vllm/worker/worker_base.py:410, in LocalOrDistributedWorkerBase.execute_model(self, execute_model_req)
#     405     if (self.observability_config is not None
#     406             and self.observability_config.collect_model_execute_time):
#     407         orig_model_execute_time = intermediate_tensors.tensors.get(
#     408             "model_execute_time", torch.tensor(0)).item()
# --> 410 output = self.model_runner.execute_model(
#     411     model_input=model_input,
#     412     kv_caches=self.kv_cache[worker_input.virtual_engine]
#     413     if self.kv_cache is not None else None,
#     414     intermediate_tensors=intermediate_tensors,
#     415     num_steps=num_steps,
#     416     **kwargs,
#     417 )
#     419 model_execute_time = time.perf_counter() - start_time
#     420 if not get_pp_group().is_last_rank:
#     421     # output is IntermediateTensors
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/ee/vllm/vllm/worker/model_runner_base.py:116, in dump_input_when_exception.<locals>._inner.<locals>._wrapper(*args, **kwargs)
#     113 @wraps(func)
#     114 def _wrapper(*args, **kwargs):
#     115     try:
# --> 116         return func(*args, **kwargs)
#     117     except Exception as err:
#     118         timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
#
# File ~/ee/vllm/vllm/worker/model_runner.py:1716, in ModelRunner.execute_model(self, model_input, kv_caches, intermediate_tensors, num_steps)
#    1713 if not bypass_model_exec:
#    1714     with set_forward_context(model_input.attn_metadata,
#    1715                              self.vllm_config, virtual_engine):
# -> 1716         hidden_or_intermediate_states = model_executable(
#    1717             input_ids=model_input.input_tokens,
#    1718             positions=model_input.input_positions,
#    1719             kv_caches=kv_caches,
#    1720             attn_metadata=model_input.attn_metadata,
#    1721             intermediate_tensors=intermediate_tensors,
#    1722             **MultiModalKwargs.as_kwargs(multi_modal_kwargs,
#    1723                                          device=self.device),
#    1724             **seqlen_agnostic_kwargs)
#    1726 if (self.observability_config is not None
#    1727         and self.observability_config.collect_model_forward_time):
#    1728     model_forward_end.record()
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/ee/vllm/vllm/model_executor/models/llama.py:1074, in LlamaForCausalLM.forward(self, input_ids, positions, kv_caches, attn_metadata, intermediate_tensors, attention_mask, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1065 output_hidden_states = (
#    1066     output_hidden_states
#    1067     if output_hidden_states is not None
#    1068     else self.config.output_hidden_states
#    1069 )
#    1070 return_dict = (
#    1071     return_dict if return_dict is not None else self.config.use_return_dict
#    1072 )
# -> 1074 outputs = self.model(
#    1075     input_ids=input_ids,
#    1076     positions=positions,
#    1077     kv_caches=kv_caches,
#    1078     attn_metadata=attn_metadata,
#    1079     attention_mask=attention_mask,
#    1080     inputs_embeds=inputs_embeds,
#    1081     use_cache=use_cache,
#    1082     output_attentions=output_attentions,
#    1083     output_hidden_states=output_hidden_states,
#    1084     return_dict=return_dict,
#    1085     lm_head=self.compute_logits,
#    1086     intermediate_tensors=intermediate_tensors,
#    1087 )
#    1089 if self.model.shallow2deep:
#    1090     self.model.stack_conf, self.model.stack_pred = (), ()
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/ee/vllm/vllm/model_executor/models/llama.py:704, in LlamaModel.forward(self, input_ids, positions, kv_caches, attn_metadata, attention_mask, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, lm_head, intermediate_tensors)
#     701                             self.stack_conf, self.stack_pred = (), ()
#     702                         break
# --> 704         hidden_states, residual = decoder_layer(
#     705             hidden_states,
#     706             kv_caches[idx],
#     707             attn_metadata,
#     708             residual,
#     709             attention_mask=attention_mask,
#     710             positions=positions,
#     711             output_attentions=output_attentions,
#     712             use_cache=use_cache,
#     713         )
#     714         # if auto_reg and self.config.optimal:
#     715         #     lm_logits = lm_head(self.norm(layer_outputs[0]))
#     716         #     exit_decision[idx] = torch.argmax(lm_logits, dim=-1)
#    (...)
#     726     # if output_attentions:
#     727     #     all_self_attns += (layer_outputs[1],)
#     729 hidden_states, _ = self.norm(hidden_states, residual)
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/ee/vllm/vllm/model_executor/models/llama.py:319, in LlamaDecoderLayer.forward(self, hidden_states, kv_cache, attn_metadata, residual, attention_mask, positions, output_attentions, use_cache, skip_mask, stack_hidden_states, parallel_mask)
#     315 else:
#     316     hidden_states, residual = self.input_layernorm(
#     317         hidden_states, residual)
# --> 319 hidden_states = self.self_attn(
#     320     positions,
#     321     hidden_states,
#     322     kv_cache,
#     323     attn_metadata,
#     324     attention_mask=attention_mask,
#     325     output_attentions=output_attentions,
#     326     use_cache=use_cache,
#     327     skip_mask=skip_mask,
#     328     stack_hidden_states=stack_hidden_states,
#     329 )
#     331 # Fully Connected
#     332 hidden_states, residual = self.post_attention_layernorm(hidden_states, residual)
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/ee/vllm/vllm/model_executor/models/llama.py:236, in LlamaAttention.forward(self, positions, hidden_states, kv_cache, attn_metadata, attention_mask, output_attentions, use_cache, skip_mask, stack_hidden_states)
#     234 q, k = self.rotary_emb(positions, q, k)
#     235 attn_output = self.attn(q, k, v, kv_cache, attn_metadata)
# --> 236 output, _ = self.o_proj(attn_output)
#     237 return output
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/megatron_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/ee/vllm/vllm/model_executor/layers/linear.py:1139, in RowParallelLinear.forward(self, input_)
#    1136 # Only fuse bias add into GEMM for rank 0 (this ensures that
#    1137 # bias will not get added more than once in TP>1 case)
#    1138 bias_ = None if (self.tp_rank > 0 or self.skip_bias_add) else self.bias
# -> 1139 output_parallel = self.quant_method.apply(self,
#    1140                                           input_parallel,
#    1141                                           bias=bias_)
#    1142 if self.reduce_results and self.tp_size > 1:
#    1143     output = tensor_model_parallel_all_reduce(output_parallel)
#
# File ~/ee/vllm/vllm/model_executor/layers/linear.py:140, in UnquantizedLinearMethod.apply(self, layer, x, bias)
#     135 def apply(self,
#     136           layer: torch.nn.Module,
#     137           x: torch.Tensor,
#     138           bias: Optional[torch.Tensor] = None) -> torch.Tensor:
# --> 140     return F.linear(x, layer.weight, bias)
#
# KeyboardInterrupt:

# %%
run_batch_inference(llm, "inputs/lmsys_100.jsonl", "results/lmsys_100_lazy.csv")
# Out:
# Processed prompts:   0%|          | 0/100 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# WARNING 03-24 12:11:44 scheduler.py:1558] Sequence group 18 is preempted by PreemptionMode.RECOMPUTE mode because there is not enough KV cache space. This can affect the end-to-end performance. Increase gpu_memory_utilization or tensor_parallel_size to provide more KV cache memory. total_num_cumulative_preemption=1
# Processed prompts:  41%|████      | 41/100 [00:14<00:19,  2.99it/s, est. speed input: 252.93 toks/s, output: 239.00 toks/s]
# WARNING 03-24 12:11:59 scheduler.py:1558] Sequence group 48 is preempted by PreemptionMode.RECOMPUTE mode because there is not enough KV cache space. This can affect the end-to-end performance. Increase gpu_memory_utilization or tensor_parallel_size to provide more KV cache memory. total_num_cumulative_preemption=51
# Processed prompts:  58%|█████▊    | 58/100 [00:25<00:32,  1.29it/s, est. speed input: 255.39 toks/s, output: 197.28 toks/s]
# WARNING 03-24 12:12:10 scheduler.py:1558] Sequence group 75 is preempted by PreemptionMode.RECOMPUTE mode because there is not enough KV cache space. This can affect the end-to-end performance. Increase gpu_memory_utilization or tensor_parallel_size to provide more KV cache memory. total_num_cumulative_preemption=101
# Processed prompts: 100%|██████████| 100/100 [00:39<00:00,  2.52it/s, est. speed input: 287.37 toks/s, output: 220.44 toks/s]
# Overall output throughput: 220.03491680150898 tokens/second

# %%
# batchsize = 4
run_batch_inference(llm, "inputs/lmsys_100.jsonl", "results/lmsys_100_off.csv")
# Out:
# Processed prompts:  56%|█████▌    | 56/100 [00:40<00:28,  1.55it/s, est. speed input: 137.51 toks/s, output: 123.71 toks/s]
# WARNING 03-24 14:44:07 scheduler.py:1558] Sequence group 58 is preempted by PreemptionMode.RECOMPUTE mode because there is not enough KV cache space. This can affect the end-to-end performance. Increase gpu_memory_utilization or tensor_parallel_size to provide more KV cache memory. total_num_cumulative_preemption=1
# Processed prompts: 100%|██████████| 100/100 [01:10<00:00,  1.42it/s, est. speed input: 162.51 toks/s, output: 125.95 toks/s]
# Overall output throughput: 125.82064581870641 tokens/second

# %%
# batchsize = 4 + totally turn off
run_batch_inference(llm, "inputs/lmsys_100.jsonl", "results/lmsys_100_off.csv")
# Out:
# Processed prompts: 100%|██████████| 100/100 [01:00<00:00,  1.67it/s, est. speed input: 189.99 toks/s, output: 146.85 toks/s]
# Overall output throughput: 146.67840422611025 tokens/second

# %%
# batchsize = 8
run_batch_inference(original_llm, "inputs/lmsys_100.jsonl", "results/lmsys_100_original.csv")
# Out:
# Processed prompts: 100%|██████████| 100/100 [00:33<00:00,  3.00it/s, est. speed input: 342.28 toks/s, output: 264.57 toks/s]
# Overall output throughput: 264.0085491509796 tokens/second

# %%
# batchsize = 4
run_batch_inference(original_llm, "inputs/lmsys_100.jsonl", "results/lmsys_100_original.csv")
# Out:
# Processed prompts: 100%|██████████| 100/100 [00:58<00:00,  1.71it/s, est. speed input: 195.53 toks/s, output: 151.14 toks/s]
# Overall output throughput: 150.94671541175452 tokens/second
